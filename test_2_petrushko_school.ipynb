# %% [markdown]
# ### Содержание
#
# #### [Задание 1: Имена](#names)
# #### [Задание 2: IP-адреса](#ip)
# #### [Задание 3: Оценка уроков](#lessons)

# %% [markdown]
# ## Задание 1: Имена<a name="names"></a>
#
# ### Исходные данные
#
# [names.txt](https://s3-us-west-2.amazonaws.com/secure.notion-static.com/c47a2634-d6cf-4b2b-9229-95fbdbe92cae/names.txt)
#
# В текстовом файле содержится набор имён.
#
# ### Задача
#
# Нужно выполнить следующие действия и вывести результат вычислений:
#
# 1. Отсортировать все имена в лексикографическом порядке.
# 2. Посчитать для каждого имени алфавитную сумму – сумму порядковых номеров букв (MAY: 13 + 1 + 25 = 39).
# 3. Умножить алфавитную сумму каждого имени на порядковый номер имени в отсортированном списке (индексация начинается с 1). Например, если MAY находится на 63 месте в списке, то результат для него будет 63 * 39 = 2457.
# 4. Сложить произведения из п. 3 для всех имен из файла и получить число.
# 5. Вывести полученную сумму.

# %%
# загружаем нужные библиотеки для обработки данных

import pandas as pd
import numpy as np
import datetime as dt

from collections import Counter

# %%
names_df = pd.read_csv('names.txt', sep=',', header=None).T
names_df.head()
# Out:
#            0
# 0       MARY
# 1   PATRICIA
# 2      LINDA
# 3    BARBARA
# 4  ELIZABETH

# %%
names_df.columns = ['names']  #название колонки
names_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5165 entries, 0 to 5164
# Data columns (total 1 columns):
# names    5164 non-null object
# dtypes: object(1)
# memory usage: 80.7+ KB

# %% [markdown]
# #### Отсортировать все имена в лексикографическом порядке

# %%
names_df = names_df.sort_values(by='names').reset_index(drop=True)
names_df.dropna(inplace=True)  # удалим отсутствующие значения
names_df.tail()
# Out:
#         names
# 5159     ZORA
# 5160  ZORAIDA
# 5161     ZULA
# 5162   ZULEMA
# 5163    ZULMA

# %%
names_df.duplicated().sum()     # дубликаты, даже если бы и были - удалять не нужно
# Out:
# 0

# %%
# удалить пробелы
names_df = names_df.replace(r'\s+','',regex=True)

# %% [markdown]
# #### Посчитать для каждого имени алфавитную сумму – сумму порядковых номеров букв (MAY: 13 + 1 + 25 = 39).

# %%
# переменная для назначения буквам порядковой цифры
num_alphabet = dict([tuple(reversed(i)) for i in enumerate('ABCDEFGHIJKLMNOPQRSTUWVXYZ', 1)]);

# функция сумирования перебора букв(цифр)
def func_name(data):
    s = sum([num_alphabet[i] for i in data])
    return s;

names_df['names_sum'] = list(map(func_name, names_df['names']))   # применение функции
names_df.head()
# Out:
#    names  names_sum
# 0  AARON         49
# 1  ABBEY         35
# 2  ABBIE         19
# 3   ABBY         30
# 4  ABDUL         40

# %%
names_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5164 entries, 0 to 5163
# Data columns (total 2 columns):
# names        5164 non-null object
# names_sum    5164 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 121.0+ KB

# %% [markdown]
# #### Умножить алфавитную сумму каждого имени на порядковый номер имени в отсортированном списке (индексация начинается с 1). Например, если MAY находится на 63 месте в списке, то результат для него будет 63 * 39 = 2457.

# %%
names_df['multiply_names'] = names_df['names_sum'] * (names_df.index + 1)
names_df
# Out:
#         names  names_sum  multiply_names
# 0       AARON         49              49
# 1       ABBEY         35              70
# 2       ABBIE         19              57
# 3        ABBY         30             120
# 4       ABDUL         40             200
# ...       ...        ...             ...
# 5159     ZORA         60          309600
# 5160  ZORAIDA         74          381914
# 5161     ZULA         60          309720
# 5162   ZULEMA         78          402714
# 5163    ZULMA         73          376972
#
# [5164 rows x 3 columns]

# %% [markdown]
# #### Сложить произведения из п. 3 для всех имен из файла и получить число и вывести полученную сумму.

# %%
'Сумма всех произведений алфавитных сумм имен на место по индексу {:,}'.format(names_df.multiply_names.sum())
# Out:
# 'Сумма всех произведений алфавитных сумм имен на место по индексу 872,141,665'

# %% [markdown]
# ## Задание 2: IP-адреса<a name="ip"></a>
#
# ### Исходные данные
#
# [hits.txt](https://s3-us-west-2.amazonaws.com/secure.notion-static.com/f4f86e5b-f716-478a-9750-5960998f852f/hits.txt)
#
# Файл состоит из строк вида: `<host>\t<ip>\t<page>\n`, где host — корневой домен, ip — IP-адрес, page — «хвост» ссылки.
#
# ### Задача
#
# Необходимо вывести 5 IP-адресов, которые встречаются в файле чаще других.

# %%
ip_df = pd.read_csv('hits.txt', sep='\t', header=None)
ip_df.head()
# Out:
#                           0               1  \
# 0     https://wikipedia.org   72.110.191.15
# 1                rambler.ru  142.93.168.247
# 2  ftp://info.itar-tass.com    90.68.118.69
# 3      http://altavista.com   18.79.197.236
# 4   ftp://tetrika-school.ru  115.26.250.226
#
#                                      2
# 0                       /friends/files
# 1                        /universe.php
# 2            /login/monitors/static/me
# 3              /friends/tasks/universe
# 4  /translate/anekdots/my-files/monday

# %%
ip_df.columns = ['host', 'ip', 'page']
ip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1247036 entries, 0 to 1247035
# Data columns (total 3 columns):
# host    1247036 non-null object
# ip      1247036 non-null object
# page    1247036 non-null object
# dtypes: object(3)
# memory usage: 28.5+ MB

# %% [markdown]
# "Пустых" данных нет. Дублкаты искать нет смысла иначе удалим 5 наиболее часто встречающихся ip
#
# **ТОП=5 наиболее часто стречающихся IP адресов**

# %%
ip_df['ip'].value_counts().head()
# Out:
# 154.157.157.156    1531
# 82.146.232.163     1505
# 226.247.119.128    1494
# 194.78.107.33      1494
# 21.143.243.182     1479
# Name: ip, dtype: int64

# %% [markdown]
# ## Задание 3: Оценка уроков<a name="lessons"></a>
#
# *В нашей школе ученики и репетиторы занимаются в специальном онлайн-классе, в котором они могут общаться друг с другом, рисовать на доске, переписываться в чате, обмениваться файлами и решать различные задачки. Информацию о каждом уроке мы записываем в базу данных в таблицу lessons. На каждом таком уроке присутствует один репетитор и один ученик. В конце урока, когда учитель и ученик покидают класс, им предлагается по желанию оценить качество пройденного урока по пятибальной шкале. Оценки мы записываем в таблицу quality.*
#
# ### Исходные данные
#
# [tech_quality.zip](https://s3-us-west-2.amazonaws.com/secure.notion-static.com/f35472a4-8bd2-49fa-b69b-a86349b6040b/tech_quality.zip)
#
# В архиве содержится четыре файла с выгрузкой строк из базы.

# %% [markdown]
# #### ПОЛЬЗОВАТЕЛИ
# Файл **users.txt** хранит информацию о пользователях:
#
# - id – уникальный идентификатор пользователя
# - role – указывает, является ли пользователь учеником (pupil) или учителем (tutor)

# %%
users_df = pd.read_csv('users.txt')
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 745 entries, 0 to 744
# Data columns (total 1 columns):
#                   id                  | role      745 non-null object
# dtypes: object(1)
# memory usage: 5.9+ KB

# %% [markdown]
# одна колонка с нестандартным названием

# %%
users_df.head()
# Out:
#                      id                  | role
# 0  --------------------------------------+-------
# 1    e28351f5-4ccb-4549-8647-d43f2b15e7b8 | pupil
# 2    4df2832a-1d63-4453-9659-43993fc35996 | tutor
# 3    bb1c0bc8-1212-452b-97a0-439d4a2169e2 | pupil
# 4    63441abe-c4da-4275-ba26-66f7dbd65dde | tutor

# %%
users_df.columns    # название столбца
# Out:
# Index(['                  id                  | role  '], dtype='object')

# %%
# разделим колонку на несколько столбцов
users_df = users_df['                  id                  | role  '].str.split(expand=True)
users_df.head()
# Out:
#                                                 0     1      2
# 0  --------------------------------------+-------  None   None
# 1            e28351f5-4ccb-4549-8647-d43f2b15e7b8     |  pupil
# 2            4df2832a-1d63-4453-9659-43993fc35996     |  tutor
# 3            bb1c0bc8-1212-452b-97a0-439d4a2169e2     |  pupil
# 4            63441abe-c4da-4275-ba26-66f7dbd65dde     |  tutor

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 745 entries, 0 to 744
# Data columns (total 3 columns):
# 0    745 non-null object
# 1    744 non-null object
# 2    743 non-null object
# dtypes: object(3)
# memory usage: 17.6+ KB

# %%
users_df.rename(columns={0: 'user_id', 2: 'role'}, inplace=True)   # переименуем столбцы
users_df.drop(1, axis=1, inplace=True)                             # удалим ненужный столбец
users_df.dropna(inplace=True)                                      # удалим строки не несущие информацию
users_df = users_df.replace(r'\s+','',regex=True)                  # удалить пробелы
users_df.head()                                                    # проверка
# Out:
#                                 user_id   role
# 1  e28351f5-4ccb-4549-8647-d43f2b15e7b8  pupil
# 2  4df2832a-1d63-4453-9659-43993fc35996  tutor
# 3  bb1c0bc8-1212-452b-97a0-439d4a2169e2  pupil
# 4  63441abe-c4da-4275-ba26-66f7dbd65dde  tutor
# 5  a1323b68-c82c-429a-8e2c-65597e648c1a  tutor

# %%
# проверим дубликаты
users_df.duplicated().sum()
# Out:
# 475

# %%
users_df[users_df.duplicated()]          # что за дубликаты
# Out:
#                                   user_id   role
# 11   63441abe-c4da-4275-ba26-66f7dbd65dde  tutor
# 13   43efce48-94b2-4412-857f-223d45969008  tutor
# 21   30a19496-bdaf-461c-abbc-2709ae520201  tutor
# 25   ad7199dd-3bf6-4d6d-8ae7-448ecf90a4eb  tutor
# 29   43efce48-94b2-4412-857f-223d45969008  tutor
# ..                                    ...    ...
# 736  8476b612-223f-4c86-9b0b-14bc04759233  tutor
# 737  ab7149fc-b650-4b6b-a368-0581f78276ea  pupil
# 738  8476b612-223f-4c86-9b0b-14bc04759233  tutor
# 740  ad7199dd-3bf6-4d6d-8ae7-448ecf90a4eb  tutor
# 742  ad7199dd-3bf6-4d6d-8ae7-448ecf90a4eb  tutor
#
# [475 rows x 2 columns]

# %%
Counter(users_df['user_id'])  # количество упоминаний
# Out:
# Counter({'e28351f5-4ccb-4549-8647-d43f2b15e7b8': 2,
#          '4df2832a-1d63-4453-9659-43993fc35996': 15,
#          'bb1c0bc8-1212-452b-97a0-439d4a2169e2': 3,
#          '63441abe-c4da-4275-ba26-66f7dbd65dde': 23,
#          'a1323b68-c82c-429a-8e2c-65597e648c1a': 2,
#          'e866fbd8-a46b-4431-9e19-f0966981f6c9': 2,
#          '4ab072ed-8a41-4ed6-9877-8f1d1fbb24d2': 1,
#          '30a19496-bdaf-461c-abbc-2709ae520201': 7,
#          '43efce48-94b2-4412-857f-223d45969008': 33,
#          '6daa4b70-1e22-46c8-bcb4-22d452e4add1': 1,
#          '2ebe48bd-0d4b-41e3-9f7e-02e006227df9': 3,
#          'e4e0a62e-5f9f-4d44-aa3f-e6827a926d9f': 2,
#          'ad7199dd-3bf6-4d6d-8ae7-448ecf90a4eb': 25,
#          'ab9a1804-b421-43d7-b052-84e15a1d8072': 1,
#          '8fe03f08-8581-430c-a590-9888ab36deb3': 24,
#          '3c5d30e3-8831-490e-a2a4-63e6ff1c33bb': 6,
#          '696c838e-c054-4e9f-a51a-50bf5660f364': 18,
#          '621ea7d1-5ffc-494a-a877-dd7d9c75bb79': 4,
#          '5ac42f66-8533-46ab-9ccf-11aead34601f': 2,
#          'b37ccae8-fc31-4ad8-8f55-ca855b23fbf6': 19,
#          'baf18014-cd9a-4932-a2c0-729438c7f831': 5,
#          'e8e6aaef-db62-41c2-aaed-395b240cbdd8': 2,
#          '07bce6b2-ef5c-450d-9565-966c41260440': 1,
#          'c21c9daa-83d8-4804-b3e8-405addcfddb8': 1,
#          '3de70be3-7ede-41c0-a5f3-90e62ab4366e': 1,
#          '8476b612-223f-4c86-9b0b-14bc04759233': 17,
#          '38e5889b-ecdb-428b-9e9d-fb786ad35702': 4,
#          '1596b1b3-43ff-4f97-948f-06d240666f52': 1,
#          '603b8641-c6f6-4d89-ac89-88e50d45aa0d': 8,
#          '9d9029a2-c81a-49f7-84ee-7696eecd2f99': 2,
#          '1071280f-18dd-40aa-bfed-248b003c09d3': 2,
#          '220a5efc-4016-498b-ab9b-ac3208e564a3': 2,
#          '61b0d9ee-1076-41ba-9ed6-ae29bdeaa2ca': 1,
#          '74cc3ea9-8e49-4ab8-98e9-be20f7f0692b': 3,
#          '2d4b8c71-3228-4293-b9ae-c2e5d826310a': 10,
#          '2babd7d7-18e1-4cf8-9a3a-b3d8f75f6396': 7,
#          '5c744ad1-83dc-4150-ba8c-217d7dce2730': 1,
#          '108b338d-ee0a-439a-8472-67e03ee5ec1b': 2,
#          '0b915033-7cbd-41b2-b27d-6295d3bfcac5': 2,
#          'fea6eede-37cc-45a1-8f3b-6548c0c5f219': 1,
#          'a6e9fdbc-2507-4290-8720-8a49ed746eb9': 4,
#          '67a1f125-35cc-4af9-abd1-369e8844330e': 1,
#          'c6718d0e-976c-4d6c-b0e0-32c770776567': 11,
#          '98a5ac48-06ae-4ead-9af2-da01d16468d7': 2,
#          'dbfbb7f2-adc9-45e4-bae7-6e0b42b0ecc7': 12,
#          'fc120a53-e799-4b94-8424-3116ee684c0e': 1,
#          '6a578a6e-39a4-4c6b-8b0a-f00f6b2dcd79': 15,
#          '40971988-f51f-4f75-a4eb-47611f27358a': 3,
#          '9573d3e8-d894-4425-a378-0939526131bb': 2,
#          '4bca9d35-b0dc-457b-b968-a3125de2d0bd': 15,
#          '88b915a6-9b3a-4580-a16c-1067d013cce7': 2,
#          '3b20e44c-352f-4a9a-9881-d1cf64e9313c': 2,
#          '7ac76f84-875d-46fb-957a-ba0e390fe539': 9,
#          '9cd423e0-39a8-4204-9c3c-dc737117dc38': 1,
#          '752423c3-9632-4a81-b325-ecfd302a1859': 9,
#          '5b41e646-ddee-4a27-a792-234bcfcaf716': 5,
#          '264a8b76-c652-4a57-8233-ffe9b2ef122c': 1,
#          'f0a766fe-155e-47a0-b81b-25274b938c82': 1,
#          '6de0b932-99f6-42ca-9e29-6cf7e0d2b2e8': 2,
#          'd0e52a15-c319-466e-ab53-fc7877566715': 9,
#          '244bbcbe-8e74-4bd3-9f0c-5a59a374e668': 2,
#          '5e28bcaf-2aa7-4e20-b071-121585004322': 2,
#          '1b99ff07-a520-44dc-9f1b-38d98c85fcb3': 13,
#          '7f2e7717-3e5d-4195-b7d5-d6c626b11be9': 1,
#          '22d2f2ca-25cc-48fd-8297-37f0cac7ef61': 2,
#          'f72b84b5-a5a0-4655-8c8b-c84a22735a27': 1,
#          'c3b6eeff-8b8a-4cca-ab15-5e8ff106917a': 3,
#          '015713e8-dac9-4cd0-9a39-6ad23146346e': 1,
#          '72897b41-a82f-4f75-91f8-85caa6f1dfb2': 2,
#          '21fff320-613f-4091-8fa9-f93fbe984f9e': 1,
#          '11530ed1-0378-46dc-b838-7885ab0988d5': 2,
#          'af6c8f96-2e2d-4021-a824-46f40117fe9b': 1,
#          '9d05dd20-fc30-4e60-a85c-a8333c5ec875': 1,
#          'a0a1ca0f-0de5-4f1c-a729-d7c4792457aa': 2,
#          '6669014e-04b3-480e-a827-3c9fe7755b76': 3,
#          '069eac09-8cb1-4223-b118-9f687eec8903': 4,
#          '20ee67a0-1c94-4828-9a09-49c16b65f4b5': 3,
#          'c0c073c8-cb9c-4ebc-ac13-472c06029591': 11,
#          '4768cfb2-6170-422b-bc6f-61262f07ac7d': 2,
#          'de50bdc3-4598-4792-9ca1-59bc5de46192': 2,
#          '50fd9341-6f4e-4105-91aa-57f14222bd3c': 2,
#          '2fa2ab62-f1b0-4036-872f-bcfd9a8686ff': 8,
#          '9b26952c-3470-4032-a9cd-f1e9d4f90ece': 5,
#          'abac0e59-f8b1-4f91-a6e9-ec062719cabd': 2,
#          'a256b2f2-acbc-4ac6-ac80-cb9806e92693': 3,
#          'e9aae3a0-04a1-4f91-9c75-7344981750de': 2,
#          '11a539ba-e942-426e-963c-03e2f8e865b9': 2,
#          'd55d2b6e-2259-47f6-9a11-b0c70827ecb8': 2,
#          'dcda0f83-3975-409f-93a9-3f8227d76ff9': 2,
#          'f86daaf7-5fac-48c3-9b2e-a573234472af': 2,
#          'cc4ce43d-60b0-4acd-8226-2f1bb90faac8': 2,
#          'e3fc595e-73cc-42d9-852c-44962d89f323': 2,
#          'be676776-8366-4c71-8a35-d58014806eb5': 3,
#          '2b573e25-bc70-406c-9896-b196b4e0a0be': 2,
#          'f6263582-489a-4abc-b19d-a2381b026e28': 2,
#          'c616e1aa-c394-4719-9883-e5e45c55f422': 1,
#          '5b9d113e-2911-4b08-9fdb-35e665dc4a62': 2,
#          'ecf338aa-2007-4340-b9ae-c4636e34730b': 2,
#          'f2f25148-97cb-422d-a5b5-b0dabbca0523': 3,
#          '39c9854e-0b3e-4269-9c7e-2122e48c4829': 3,
#          'f4045efd-d596-4691-b7db-d3e64036f743': 2,
#          'f3b12049-e63f-42a8-951b-3db0809c62c8': 1,
#          'f6fe6efa-5f8f-44d9-849f-2f2b4d42a8e1': 2,
#          '8906a07a-b33d-4371-8b34-6d217cf31c73': 3,
#          '28229364-321a-46f7-a683-2a039d649389': 1,
#          '0bd5646f-8b43-4494-b773-8d8b22107af8': 5,
#          'f5ea4e53-15f8-41a5-96de-f20dc162eb4b': 2,
#          '435be489-4ca3-46aa-bbfa-598abdeb454e': 6,
#          '22175a94-271e-4aed-a978-87d8b6e325d9': 2,
#          '6183945e-29ba-4c1d-b3eb-e68f8aa1bf00': 2,
#          '4b554497-2a62-4244-8707-7798bde57c1d': 2,
#          '8480e88d-7730-460f-9704-0776700bdb3c': 1,
#          '24e6ab3e-7057-4d91-8a4c-a159da6cf0b5': 3,
#          '9f4aab9a-7ad6-4eac-bfbe-18b2fdab4bb3': 1,
#          '9c2ccb50-b72b-49c1-95b3-3e9cee9d512e': 3,
#          'b9cc677b-8691-43a4-b730-62a60665d231': 2,
#          '5b00e607-13c0-40e4-aacf-22142d339074': 4,
#          '4f9a197c-02f6-4b83-bfc0-c29a7ca37e91': 8,
#          'e2e86c24-d319-40f0-8461-e46d041adb8b': 1,
#          'b1fe2c06-d284-4698-9f07-495c8f991700': 4,
#          'c0ea86b7-b6cb-4da6-94d7-f0dc2175f5b2': 4,
#          'ac9d73e0-1b42-4031-8edd-2dce14fa3305': 2,
#          '4045c46d-2be7-4593-af95-bc86ca95b296': 1,
#          'dfd12ba1-8a59-4355-919c-2e2adcc5ff5c': 2,
#          '64812051-5ea2-4f11-ab9f-5b1fd4e9b6a6': 1,
#          '87947747-2e64-4659-9699-010576a37f24': 7,
#          '431f479e-37c3-4160-bd24-211e798018e7': 1,
#          '05b9e80b-06e7-4d3d-9845-24fa7c5fb702': 3,
#          'd8b85ebe-487c-4e1f-bac5-0acad6c9afe3': 2,
#          '0d688d4b-b5b7-4519-ab32-785138b3a330': 2,
#          '21a13ace-57b6-492e-8ba2-7f1e3a7945e1': 1,
#          'e4305046-053d-4a41-9dba-7128a45ebc39': 1,
#          '52c4577e-2e99-41cc-ad15-31af1975db24': 2,
#          '0f58f0b1-3b88-4abe-b825-f631cc326370': 1,
#          'ef899367-5dfb-406e-85b3-2db3ffad8ee2': 1,
#          'c365f2b5-6c48-4df2-aa38-99642f241212': 1,
#          '70d4f068-44be-4db7-b476-ceb4be223f0d': 1,
#          'b054eff6-02e8-4893-af77-9d3b0a276fed': 3,
#          'b4e08cac-ebc8-40df-804e-b216fb6da96d': 1,
#          'a480c311-f66c-4cb7-a943-59322ea3687c': 1,
#          '64e8ade7-0f51-4929-99af-bdb543ba20f3': 2,
#          'c31d06f1-b667-489f-af70-d2c88402826c': 2,
#          'd7ae6d0c-c68b-4848-b99e-403d689a299c': 2,
#          'b56211c8-cb1f-4b15-8c84-67bd8139f7b6': 1,
#          '89775bc1-339d-4fed-9dd6-ba915a6c3e46': 1,
#          'e05a16a8-c1b8-48f0-be92-34ebdd834b72': 1,
#          '3c196a34-993d-4619-ba1c-3768a40920e7': 2,
#          'f51d0b63-a08b-4850-8400-92a14ab441f0': 1,
#          'c6267ed8-25a6-46ef-92a1-2dce60810bbd': 2,
#          '2631e73a-a5c7-4c97-81f3-3d066f38b20e': 2,
#          'fa09b298-673d-4806-8863-d7c22383a9e3': 1,
#          'f1de36ff-5b10-4e8b-81b4-936343b09053': 1,
#          '154b5bfa-f2d3-4908-8307-8563883a06fe': 2,
#          'dff15fcb-7194-4046-8c94-7fd0acbbd754': 1,
#          'ee3b493b-48df-479a-b641-3f3bd7fa205c': 2,
#          '4d5e14f8-5ee7-4b3c-bc24-f872f8b9a994': 1,
#          '20ee1a31-af77-4864-bd64-260cf7733503': 1,
#          'ab7149fc-b650-4b6b-a368-0581f78276ea': 3,
#          '5841346b-33fd-4735-9285-d4a3faa365ae': 1,
#          '2dc9cc26-03a4-4375-a547-6ef6f28b41a4': 2,
#          'a170f42b-7bfc-4129-aa40-47c0f12cc53c': 1,
#          'a169a848-fedd-46a1-958a-2f53802dca0b': 1,
#          '7f10e33e-0644-480a-98a1-17cb3a16e3b5': 1,
#          '29154236-2eb6-4143-945d-4c7eb5d632c8': 1,
#          '727938d3-685d-4224-a068-f606c38282fd': 1,
#          '916d06fb-3279-4d2c-b449-c56be1cdeb7e': 2,
#          'e09c4a92-2f55-405e-85c9-6aa62c0f9226': 1,
#          '45f616d9-e482-4df3-89eb-7d2db6672828': 1,
#          'be881043-717f-42c6-aad3-c9ac7a8c279a': 1,
#          '7ab44ff1-45ef-4c43-b4ae-870d38f53677': 2,
#          'ca7bc456-dd66-4ffc-a395-6e3b4a3bb733': 1,
#          '89ecabe9-7768-4cc3-a126-afa0fba1052a': 1,
#          'fe166edb-196c-45ed-8602-fc15fdbe4a20': 1,
#          '6b42163e-0959-44ad-9a77-5214c2780c88': 1,
#          'd23302cf-1d48-4e10-aceb-6f1066319c91': 1,
#          '9615a9e5-1963-4f1d-b5e8-7e43e103c286': 1,
#          '4e0f8706-9e67-4b08-812f-ceaa54fbd84d': 1,
#          'c8ff5fea-4d0a-4a87-81e4-df6c2082aa0c': 1,
#          '4157b5ce-9393-4e3b-a697-5f287219c3d2': 2,
#          '39587418-fa78-4a09-b3fe-71de8b0fc2f8': 1,
#          'd94899c2-7e32-4d72-b128-be88bb266e5b': 1,
#          '3407e6d6-975f-4518-a48f-5823d70b3b64': 1,
#          'eb47bfc8-ff11-42cd-a48b-1c88aca067f7': 2,
#          '1c39e78f-6ded-4b2e-83d6-036ca34ecfdc': 2,
#          'a5d4fb88-2cf6-4109-84c6-eea51f29f3e4': 1,
#          'deb8fe84-9cae-4697-87dc-75293bb1a558': 1,
#          'd754610c-c4ac-46f5-9b02-8067e0f8a01d': 1,
#          '15d896a9-b7e8-43ff-8112-e15b858f0214': 1,
#          'd7eb5119-a574-43ff-9de7-4c0b84f67d43': 1,
#          '4758da03-f56d-4cf6-a58d-17dd3d7d8445': 1,
#          'bfc85375-16eb-4591-8f85-9e1b354ba81a': 1,
#          'ef69abc9-0439-482e-9b68-2b864ab6f7e2': 2,
#          'f6ab80c2-9674-44de-bc0e-02c006bbd986': 1,
#          '7d5cb1b9-a223-49e3-9cd3-70ea664a9383': 1,
#          'dbc0ff98-e23b-4bbb-b735-a398618bdcd0': 1,
#          '025017dc-60b8-4dfa-8e6b-59eb84b868bd': 1,
#          'c7123879-75e7-4957-b809-f2f684499b67': 1,
#          'cc296af5-8aaf-41da-8651-99553e752ec9': 1,
#          'ea93b5ae-6359-4194-9de3-f24b7037184d': 1,
#          '4332bb79-8885-432e-a56c-d1324dde1987': 1,
#          '5ce12e79-b625-422b-80bd-b7af827e70e1': 2,
#          'fb43c980-8fc7-4c9f-8a8a-5f611028613d': 1,
#          '3c9ccac9-6180-4e74-993e-c83f15a9b6c8': 1,
#          '6ea8907d-684a-4d09-946a-4507c41fc047': 1,
#          'a505da80-6d85-47ac-875a-53d58a11ace8': 1,
#          'ddc20774-b555-44e8-ad1a-4e1f1ad77410': 1,
#          '010a4b07-5103-4611-bfe4-7d79ccf17333': 1,
#          '3d6c8365-ca24-47c4-ba8a-b3d793b32a27': 1,
#          '96d9da9a-e1e0-459e-ba8f-724d51d5b3cf': 1,
#          '7fa0ba61-9c69-49cd-9f45-e7f16d89ccb6': 1,
#          '762edd55-d72c-4d46-9e6f-53aa2db374f6': 1,
#          '0f2c2ebb-a0a5-46ab-8c2f-1d4992997888': 1,
#          '3d157b10-e736-4496-a530-5d4f443eea5c': 1,
#          'af26be03-c16c-4704-91be-f6e4af54ef80': 1,
#          '8c37cc1b-7650-4307-80e7-949a904e2a33': 1,
#          '6ebdc246-e8a3-43b6-8a55-40c4789000ad': 2,
#          '7b913e7a-cfb4-4383-93c7-ddccbafc8850': 1,
#          '9fb1e9b4-9765-486f-ac51-4444213e39ca': 1,
#          'b323a494-40c0-4522-8d63-4d4d591a1def': 1,
#          '3c94e328-9fb6-44d8-baa8-46a81e214ceb': 1,
#          '9a192e4d-473f-4f81-af68-1b422bd814f6': 1,
#          '720868c1-3d34-44a7-a23e-6c4a0fac609a': 1,
#          '582e6abb-dd9a-42fa-b441-455eac28327e': 1,
#          'd3364cf3-46cc-4e64-ad11-70a069f7c049': 1,
#          'f76609c8-ba5d-4818-9b57-097debc90cab': 1})

# %%
# удаляем дубликаты
users_df.drop_duplicates(inplace=True)
users_df.head()
# Out:
#                                 user_id   role
# 1  e28351f5-4ccb-4549-8647-d43f2b15e7b8  pupil
# 2  4df2832a-1d63-4453-9659-43993fc35996  tutor
# 3  bb1c0bc8-1212-452b-97a0-439d4a2169e2  pupil
# 4  63441abe-c4da-4275-ba26-66f7dbd65dde  tutor
# 5  a1323b68-c82c-429a-8e2c-65597e648c1a  tutor

# %%
users_df.shape
# Out:
# (268, 2)

# %% [markdown]
# #### УРОКИ
# Файл **lessons.txt** содержит следующие поля:
#
# - id – уникальный идентификатор урока
# - event_id – идентификатор, связывающий уроки с файлом participants. У нескольких уроков может быть один и тот же event_id
# - subject – предмет урока, строка
# - scheduled_time – время начала урока, в формате ГГГГ-ММ-ДД чч:мм:сс (иногда есть еще миллисекунды). Время указано в UTC

# %%
lessons_df = pd.read_csv('lessons.txt', sep='|')
lessons_df
# Out:
#                                   id                     event_id    subject   \
# 0    --------------------------------------+-------...         NaN        NaN
# 1                1e7bb408-cfef-4a9f-8328-351c9483a64c      38114.0   phys
# 2                6d8e59d9-a7c8-4bb3-8ff3-99cd07acdf1a      51568.0   it
# 3                62e1a078-33de-47c1-99d2-845b1daca56f      52790.0   hist
# 4                00fc6685-f53a-49bb-b960-5e0042fd3852      51341.0   phys
# ..                                                 ...         ...        ...
# 375              056c3d91-dce7-4071-91d3-1de816ee63a3      51001.0   hist
# 376              c64a1daf-d7f5-4c8c-ac9f-df634d77327b      50304.0   bio
# 377              aa7702bc-5271-469c-a1c2-b7e814fd7e20      49880.0   bio
# 378              8643fa00-217a-42ae-a27d-e6f47c0501f1      55449.0   bio
# 379                                         (378 rows)         NaN        NaN
#
#            scheduled_time
# 0                            NaN
# 1            2020-01-19 12:00:00
# 2            2020-01-19 13:00:00
# 3            2020-01-19 13:00:00
# 4            2020-01-17 12:00:00
# ..                           ...
# 375          2020-01-17 12:45:00
# 376          2020-01-11 11:00:00
# 377          2020-01-16 15:00:00
# 378          2020-01-19 12:15:00
# 379                          NaN
#
# [380 rows x 4 columns]

# %%
lessons_df.dropna(inplace=True)                                # удалим строки не несущие информацию
lessons_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 378 entries, 1 to 378
# Data columns (total 4 columns):
#                   id                      378 non-null object
#  event_id                                 378 non-null float64
#  subject                                  378 non-null object
#        scheduled_time                     378 non-null object
# dtypes: float64(1), object(3)
# memory usage: 14.8+ KB

# %% [markdown]
# Пустых значений нет, нужно изменить названия столбцов (убрать пробелы), изменить типы данных: для event_id - целочисленнный формат, для времени - формат дат по московскому времени.

# %%
lessons_df.columns = ['lesson_id', 'event_id', 'subject', 'scheduled_time']                   # название столбцов
lessons_df['event_id'] = lessons_df['event_id'].astype('int')                                 # целочисленные данные

# %%
lessons_df['scheduled_time'] = pd.to_datetime(lessons_df['scheduled_time']).dt.round('1S')    # округляем до секунды
lessons_df.head()
# Out:
#                                 lesson_id  event_id    subject  \
# 1   1e7bb408-cfef-4a9f-8328-351c9483a64c      38114   phys
# 2   6d8e59d9-a7c8-4bb3-8ff3-99cd07acdf1a      51568   it
# 3   62e1a078-33de-47c1-99d2-845b1daca56f      52790   hist
# 4   00fc6685-f53a-49bb-b960-5e0042fd3852      51341   phys
# 5   4cadf623-82e6-422f-a342-acf978302fb2      55048   phys
#
#        scheduled_time
# 1 2020-01-19 12:00:00
# 2 2020-01-19 13:00:00
# 3 2020-01-19 13:00:00
# 4 2020-01-17 12:00:00
# 5 2020-01-19 14:00:00

# %%
# время по Москве = UTC+3, оставляем информацию о дне проведения урока
lessons_df['moscow_date'] = (lessons_df['scheduled_time'] + dt.timedelta(hours=3)).astype('datetime64[D]')  
lessons_df.head()
# Out:
#                                 lesson_id  event_id    subject  \
# 1   1e7bb408-cfef-4a9f-8328-351c9483a64c      38114   phys
# 2   6d8e59d9-a7c8-4bb3-8ff3-99cd07acdf1a      51568   it
# 3   62e1a078-33de-47c1-99d2-845b1daca56f      52790   hist
# 4   00fc6685-f53a-49bb-b960-5e0042fd3852      51341   phys
# 5   4cadf623-82e6-422f-a342-acf978302fb2      55048   phys
#
#        scheduled_time moscow_date
# 1 2020-01-19 12:00:00  2020-01-19
# 2 2020-01-19 13:00:00  2020-01-19
# 3 2020-01-19 13:00:00  2020-01-19
# 4 2020-01-17 12:00:00  2020-01-17
# 5 2020-01-19 14:00:00  2020-01-19

# %%
lessons_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 378 entries, 1 to 378
# Data columns (total 5 columns):
# lesson_id         378 non-null object
# event_id          378 non-null int32
# subject           378 non-null object
# scheduled_time    378 non-null datetime64[ns]
# moscow_date       378 non-null datetime64[ns]
# dtypes: datetime64[ns](2), int32(1), object(2)
# memory usage: 16.2+ KB

# %%
lessons_df.duplicated().sum()
# Out:
# 0

# %%
lessons_df.subject.unique()
# Out:
# array([' phys    ', ' it      ', ' hist    ', ' bio     '], dtype=object)

# %%
lessons_df.lesson_id.unique()
# Out:
# array([' 1e7bb408-cfef-4a9f-8328-351c9483a64c ',
#        ' 6d8e59d9-a7c8-4bb3-8ff3-99cd07acdf1a ',
#        ' 62e1a078-33de-47c1-99d2-845b1daca56f ',
#        ' 00fc6685-f53a-49bb-b960-5e0042fd3852 ',
#        ' 4cadf623-82e6-422f-a342-acf978302fb2 ',
#        ' f3f15fee-ad91-429c-8b1e-faeb42f78f58 ',
#        ' e597a79a-3f68-4d15-bc77-c7000bcf8e52 ',
#        ' 44e2e74c-8481-41a2-bd64-f6af688169b7 ',
#        ' ea6f0bf3-bcfc-4555-9b16-cc2cfe722e17 ',
#        ' 7d56b43a-d137-446d-8570-8d7d5ccbaee9 ',
#        ' 38a8b0ea-ff54-42cf-ab5b-742700ffcd0a ',
#        ' b1a122d7-b1c3-43c9-86e1-ec5e40456a3b ',
#        ' d8816fa1-dd30-4a4b-8bd1-32285dec279f ',
#        ' ec953406-b4a3-416a-b1b6-4c4853995047 ',
#        ' 952674d6-5d00-4797-95f7-6686014a6b65 ',
#        ' 7c60dff9-7145-4a89-8310-e5ad951f7758 ',
#        ' 457accf4-bd99-4b9d-b540-ef200e65afbd ',
#        ' ba12a5df-1ef8-4e3d-909a-798958d36689 ',
#        ' 403707fd-b110-4216-b678-6dbc92eb6fad ',
#        ' 368373f6-e7ad-4bb5-a5ea-073fda7e890d ',
#        ' f579351b-177c-4c1c-850a-58bbda8b0b22 ',
#        ' 056c3d91-dce7-4071-91d3-1de816ee63a3 ',
#        ' c64a1daf-d7f5-4c8c-ac9f-df634d77327b ',
#        ' aa7702bc-5271-469c-a1c2-b7e814fd7e20 ',
#        ' 8643fa00-217a-42ae-a27d-e6f47c0501f1 '], dtype=object)

# %%
lessons_df.lesson_id = lessons_df.lesson_id.replace(r'\s+','',regex=True)           # удаляем пробелы
lessons_df.subject = lessons_df.subject.replace(r'\s+','',regex=True)

# %% [markdown]
# #### УЧАСТНИКИ
# Файл **participants.txt** позволяет связать урок с его участниками. Он содержит следующие поля:
#
# - user_id – идентификатор пользователя (указывает на запись в файле users.txt)
# - event_id – идентификатор, связывающий урок с участником. Чтобы понять, какие пользователи были на уроке Х, нужно найти в файле participants.txt строки, у которых event_id совпадает с event_id урока Х.

# %%
participants_df = pd.read_csv('participants.txt', sep='|')
participants_df
# Out:
#                                              event_id   \
# 0    ----------+--------------------------------------
# 1                                               38114
# 2                                               38114
# 3                                               51568
# 4                                               51568
# ..                                                 ...
# 740                                             49880
# 741                                             49880
# 742                                             55449
# 743                                             55449
# 744                                         (743 rows)
#
#                    user_id
# 0                                      NaN
# 1     e28351f5-4ccb-4549-8647-d43f2b15e7b8
# 2     4df2832a-1d63-4453-9659-43993fc35996
# 3     bb1c0bc8-1212-452b-97a0-439d4a2169e2
# 4     63441abe-c4da-4275-ba26-66f7dbd65dde
# ..                                     ...
# 740   8476b612-223f-4c86-9b0b-14bc04759233
# 741   582e6abb-dd9a-42fa-b441-455eac28327e
# 742   ad7199dd-3bf6-4d6d-8ae7-448ecf90a4eb
# 743   d3364cf3-46cc-4e64-ad11-70a069f7c049
# 744                                    NaN
#
# [745 rows x 2 columns]

# %%
participants_df.dropna(inplace=True)                                         # удалим строки не несущие информацию
participants_df.columns = ['event_id', 'user_id']                            # название столбцов
participants_df['event_id'] = participants_df['event_id'].astype('int')      # изменим тип данных
participants_df = participants_df.replace(r'\s+','',regex=True)              # удаляем пробелы
participants_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 743 entries, 1 to 743
# Data columns (total 2 columns):
# event_id    743 non-null int64
# user_id     743 non-null object
# dtypes: int64(1), object(1)
# memory usage: 17.4+ KB

# %%
participants_df.duplicated().sum()
# Out:
# 98

# %% [markdown]
# так как в базе связывается однозначно уникальный урок с уникальным участником - можем удалить дубликаты из таблицы.

# %%
participants_df.drop_duplicates(inplace=True)                                # удалим дубликаты
participants_df.shape
# Out:
# (645, 2)

# %% [markdown]
# #### ОЦЕНКИ
# Файл **quality.txt** содержит следующие поля:
#
# - lesson_id – идентификатор урока, указывающий на запись в таблице lessons.txt. У нескольких строчек из этого файла может быть один и тот же lesson_id, потому что оценок за урок может быть несколько (в случае, когда и ученик, и репетитор оценили качество урока)
# - tech_quality – оценка качества урока. Это число от 1 до 5. Иногда его может не быть, если пользователь не выставил оценку.

# %%
quality_df = pd.read_csv('quality.txt', sep='|')
quality_df
# Out:
#                               lesson_id                 tech_quality
# 0    --------------------------------------+-------...            NaN
# 1                6d8e59d9-a7c8-4bb3-8ff3-99cd07acdf1a               5
# 2                62e1a078-33de-47c1-99d2-845b1daca56f               5
# 3                62e1a078-33de-47c1-99d2-845b1daca56f               5
# 4                00fc6685-f53a-49bb-b960-5e0042fd3852               5
# ..                                                 ...            ...
# 362              aa7702bc-5271-469c-a1c2-b7e814fd7e20               5
# 363              8643fa00-217a-42ae-a27d-e6f47c0501f1               5
# 364              7a15af58-39d0-4207-bfdf-3fa176b7fb4e               5
# 365              7a15af58-39d0-4207-bfdf-3fa176b7fb4e               5
# 366                                         (365 rows)            NaN
#
# [367 rows x 2 columns]

# %%
quality_df.dropna(inplace=True)                                # удалим строки не несущие информацию
quality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 1 to 365
# Data columns (total 2 columns):
#               lesson_id                   365 non-null object
#  tech_quality                             365 non-null object
# dtypes: object(2)
# memory usage: 8.6+ KB

# %%
quality_df.columns = ['lesson_id', 'tech_quality']                                # название столбцов
quality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 1 to 365
# Data columns (total 2 columns):
# lesson_id       365 non-null object
# tech_quality    365 non-null object
# dtypes: object(2)
# memory usage: 8.6+ KB

# %%
quality_df['tech_quality'].unique()        # проверим в каком состоянии оценки
# Out:
# array(['            5', '            2', '            4', '             ',
#        '            3', '            1'], dtype=object)

# %%
# уберем пробелы, заменим тип данных
quality_df['tech_quality'] = quality_df['tech_quality'].apply(pd.to_numeric, errors='coerce')
quality_df['tech_quality'].unique()
# Out:
# array([ 5.,  2.,  4., nan,  3.,  1.])

# %%
quality_df = quality_df.replace(r'\s+','',regex=True)              # удаляем пробелы
quality_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 365 entries, 1 to 365
# Data columns (total 2 columns):
# lesson_id       365 non-null object
# tech_quality    349 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 8.6+ KB

# %%
quality_df.head()
# Out:
#                               lesson_id  tech_quality
# 1  6d8e59d9-a7c8-4bb3-8ff3-99cd07acdf1a           5.0
# 2  62e1a078-33de-47c1-99d2-845b1daca56f           5.0
# 3  62e1a078-33de-47c1-99d2-845b1daca56f           5.0
# 4  00fc6685-f53a-49bb-b960-5e0042fd3852           5.0
# 5  00fc6685-f53a-49bb-b960-5e0042fd3852           5.0

# %%
quality_df.describe()
# Out:
#        tech_quality
# count    349.000000
# mean       4.793696
# std        0.650257
# min        1.000000
# 25%        5.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# исходя из условия подачи данных - дубликаты не нужно искать

# %% [markdown]
# ### Задача
#
# Нужно найти, какой из репетиторов получал самую низкую среднюю оценку качества после уроков по физике за каждый день, и вывести эту оценку.
#
# Примечания:
#
# - Необходимо учитывать оценки и учителей, и учеников.
# - Нужно учитывать только тех учителей, за уроки по физике которых в этот день стоит хотя бы одна оценка.
# - Начало урока для решения задачи должно учитываться по московскому времени.
# - При расчёте среднего значения не нужно учитывать ситуации, когда пользователь не выставил оценку.
# - Если у нескольких учителей после расчёта совпадают средние значения, можно вывести любого из них.
#
# Решение должно выглядеть примерно так:
#
# [result](https://www.notion.so/98bcad0395144058ac50c53ae07590aa)

# %% [markdown]
# Из базы пользователей выберем только учителей

# %%
users_df.head()
# Out:
#                                 user_id   role
# 1  e28351f5-4ccb-4549-8647-d43f2b15e7b8  pupil
# 2  4df2832a-1d63-4453-9659-43993fc35996  tutor
# 3  bb1c0bc8-1212-452b-97a0-439d4a2169e2  pupil
# 4  63441abe-c4da-4275-ba26-66f7dbd65dde  tutor
# 5  a1323b68-c82c-429a-8e2c-65597e648c1a  tutor

# %%
users_df.shape
# Out:
# (268, 2)

# %%
tutor = users_df['role'] == 'tutor'
users_tutor = users_df.query('@tutor')    # база id только преподователей
users_tutor
# Out:
#                                   user_id   role
# 2    4df2832a-1d63-4453-9659-43993fc35996  tutor
# 4    63441abe-c4da-4275-ba26-66f7dbd65dde  tutor
# 5    a1323b68-c82c-429a-8e2c-65597e648c1a  tutor
# 8    30a19496-bdaf-461c-abbc-2709ae520201  tutor
# 9    43efce48-94b2-4412-857f-223d45969008  tutor
# ..                                    ...    ...
# 543  1c39e78f-6ded-4b2e-83d6-036ca34ecfdc  tutor
# 566  d754610c-c4ac-46f5-9b02-8067e0f8a01d  tutor
# 600  4758da03-f56d-4cf6-a58d-17dd3d7d8445  tutor
# 627  c7123879-75e7-4957-b809-f2f684499b67  tutor
# 730  9a192e4d-473f-4f81-af68-1b422bd814f6  tutor
#
# [65 rows x 2 columns]

# %%
lessons_df.head()
# Out:
#                               lesson_id  event_id subject      scheduled_time  \
# 1  1e7bb408-cfef-4a9f-8328-351c9483a64c     38114    phys 2020-01-19 12:00:00
# 2  6d8e59d9-a7c8-4bb3-8ff3-99cd07acdf1a     51568      it 2020-01-19 13:00:00
# 3  62e1a078-33de-47c1-99d2-845b1daca56f     52790    hist 2020-01-19 13:00:00
# 4  00fc6685-f53a-49bb-b960-5e0042fd3852     51341    phys 2020-01-17 12:00:00
# 5  4cadf623-82e6-422f-a342-acf978302fb2     55048    phys 2020-01-19 14:00:00
#
#   moscow_date
# 1  2020-01-19
# 2  2020-01-19
# 3  2020-01-19
# 4  2020-01-17
# 5  2020-01-19

# %%
lessons_df.shape
# Out:
# (378, 5)

# %%
participants_df.head()
# Out:
#    event_id                               user_id
# 1     38114  e28351f5-4ccb-4549-8647-d43f2b15e7b8
# 2     38114  4df2832a-1d63-4453-9659-43993fc35996
# 3     51568  bb1c0bc8-1212-452b-97a0-439d4a2169e2
# 4     51568  63441abe-c4da-4275-ba26-66f7dbd65dde
# 5     52790  a1323b68-c82c-429a-8e2c-65597e648c1a

# %%
participants_df.shape
# Out:
# (645, 2)

# %% [markdown]
# Составим базу событий с участием только преподователей - какие уроки вели преподователи

# %%
tutor_event = pd.merge(users_tutor, participants_df, on='user_id')
tutor_event.columns = ['tutor_id', 'role', 'event_id']
tutor_event
# Out:
#                                  tutor_id   role  event_id
# 0    4df2832a-1d63-4453-9659-43993fc35996  tutor     38114
# 1    4df2832a-1d63-4453-9659-43993fc35996  tutor     38111
# 2    4df2832a-1d63-4453-9659-43993fc35996  tutor     56195
# 3    4df2832a-1d63-4453-9659-43993fc35996  tutor     50880
# 4    4df2832a-1d63-4453-9659-43993fc35996  tutor     51450
# ..                                    ...    ...       ...
# 324  1c39e78f-6ded-4b2e-83d6-036ca34ecfdc  tutor     55480
# 325  d754610c-c4ac-46f5-9b02-8067e0f8a01d  tutor     55441
# 326  4758da03-f56d-4cf6-a58d-17dd3d7d8445  tutor     55572
# 327  c7123879-75e7-4957-b809-f2f684499b67  tutor     55660
# 328  9a192e4d-473f-4f81-af68-1b422bd814f6  tutor     54327
#
# [329 rows x 3 columns]

# %%
phys = lessons_df['subject'] == 'phys'                     # только уроки по физике
lessons_phys = lessons_df.query('@phys')
lessons_phys
# Out:
#                                 lesson_id  event_id subject  \
# 1    1e7bb408-cfef-4a9f-8328-351c9483a64c     38114    phys
# 4    00fc6685-f53a-49bb-b960-5e0042fd3852     51341    phys
# 5    4cadf623-82e6-422f-a342-acf978302fb2     55048    phys
# 7    e597a79a-3f68-4d15-bc77-c7000bcf8e52     53026    phys
# 9    ea6f0bf3-bcfc-4555-9b16-cc2cfe722e17     51645    phys
# ..                                    ...       ...     ...
# 367  e90f529b-1061-4efd-9bba-f73ecee2ef27     55490    phys
# 368  f0002160-e57e-4e90-ac7e-c8fcdbbae26f     41963    phys
# 369  8a1bac54-c5c6-47c9-8fdb-36d01384eaae     55881    phys
# 370  457accf4-bd99-4b9d-b540-ef200e65afbd     49007    phys
# 372  403707fd-b110-4216-b678-6dbc92eb6fad     41964    phys
#
#          scheduled_time moscow_date
# 1   2020-01-19 12:00:00  2020-01-19
# 4   2020-01-17 12:00:00  2020-01-17
# 5   2020-01-19 14:00:00  2020-01-19
# 7   2020-01-19 15:00:00  2020-01-19
# 9   2020-01-19 14:00:00  2020-01-19
# ..                  ...         ...
# 367 2020-01-19 08:00:00  2020-01-19
# 368 2020-01-19 09:00:00  2020-01-19
# 369 2020-01-19 15:00:00  2020-01-19
# 370 2020-01-19 05:00:00  2020-01-19
# 372 2020-01-19 11:00:00  2020-01-19
#
# [184 rows x 5 columns]

# %% [markdown]
# Объединяем базу уроков по физике и оценок за урок

# %%
lessons_phys_quality = pd.merge(lessons_phys, quality_df, on='lesson_id', how='left')
lessons_phys_quality
# Out:
#                                 lesson_id  event_id subject  \
# 0    1e7bb408-cfef-4a9f-8328-351c9483a64c     38114    phys
# 1    00fc6685-f53a-49bb-b960-5e0042fd3852     51341    phys
# 2    00fc6685-f53a-49bb-b960-5e0042fd3852     51341    phys
# 3    4cadf623-82e6-422f-a342-acf978302fb2     55048    phys
# 4    e597a79a-3f68-4d15-bc77-c7000bcf8e52     53026    phys
# ..                                    ...       ...     ...
# 243  8a1bac54-c5c6-47c9-8fdb-36d01384eaae     55881    phys
# 244  457accf4-bd99-4b9d-b540-ef200e65afbd     49007    phys
# 245  457accf4-bd99-4b9d-b540-ef200e65afbd     49007    phys
# 246  403707fd-b110-4216-b678-6dbc92eb6fad     41964    phys
# 247  403707fd-b110-4216-b678-6dbc92eb6fad     41964    phys
#
#          scheduled_time moscow_date  tech_quality
# 0   2020-01-19 12:00:00  2020-01-19           NaN
# 1   2020-01-17 12:00:00  2020-01-17           5.0
# 2   2020-01-17 12:00:00  2020-01-17           5.0
# 3   2020-01-19 14:00:00  2020-01-19           5.0
# 4   2020-01-19 15:00:00  2020-01-19           5.0
# ..                  ...         ...           ...
# 243 2020-01-19 15:00:00  2020-01-19           NaN
# 244 2020-01-19 05:00:00  2020-01-19           5.0
# 245 2020-01-19 05:00:00  2020-01-19           4.0
# 246 2020-01-19 11:00:00  2020-01-19           NaN
# 247 2020-01-19 11:00:00  2020-01-19           5.0
#
# [248 rows x 6 columns]

# %% [markdown]
# *За какие-то уроки оценки не ставились*

# %% [markdown]
# **Объединяем базу уроков по физике с оценками за урок и базу учителей**

# %%
lessons_phys_quality = lessons_phys_quality.merge(tutor_event, on='event_id', how='left')
lessons_phys_quality
# Out:
#                                 lesson_id  event_id subject  \
# 0    1e7bb408-cfef-4a9f-8328-351c9483a64c     38114    phys
# 1    00fc6685-f53a-49bb-b960-5e0042fd3852     51341    phys
# 2    00fc6685-f53a-49bb-b960-5e0042fd3852     51341    phys
# 3    4cadf623-82e6-422f-a342-acf978302fb2     55048    phys
# 4    e597a79a-3f68-4d15-bc77-c7000bcf8e52     53026    phys
# ..                                    ...       ...     ...
# 243  8a1bac54-c5c6-47c9-8fdb-36d01384eaae     55881    phys
# 244  457accf4-bd99-4b9d-b540-ef200e65afbd     49007    phys
# 245  457accf4-bd99-4b9d-b540-ef200e65afbd     49007    phys
# 246  403707fd-b110-4216-b678-6dbc92eb6fad     41964    phys
# 247  403707fd-b110-4216-b678-6dbc92eb6fad     41964    phys
#
#          scheduled_time moscow_date  tech_quality  \
# 0   2020-01-19 12:00:00  2020-01-19           NaN
# 1   2020-01-17 12:00:00  2020-01-17           5.0
# 2   2020-01-17 12:00:00  2020-01-17           5.0
# 3   2020-01-19 14:00:00  2020-01-19           5.0
# 4   2020-01-19 15:00:00  2020-01-19           5.0
# ..                  ...         ...           ...
# 243 2020-01-19 15:00:00  2020-01-19           NaN
# 244 2020-01-19 05:00:00  2020-01-19           5.0
# 245 2020-01-19 05:00:00  2020-01-19           4.0
# 246 2020-01-19 11:00:00  2020-01-19           NaN
# 247 2020-01-19 11:00:00  2020-01-19           5.0
#
#                                  tutor_id   role
# 0    4df2832a-1d63-4453-9659-43993fc35996  tutor
# 1    30a19496-bdaf-461c-abbc-2709ae520201  tutor
# 2    30a19496-bdaf-461c-abbc-2709ae520201  tutor
# 3    43efce48-94b2-4412-857f-223d45969008  tutor
# 4    43efce48-94b2-4412-857f-223d45969008  tutor
# ..                                    ...    ...
# 243  c6718d0e-976c-4d6c-b0e0-32c770776567  tutor
# 244  696c838e-c054-4e9f-a51a-50bf5660f364  tutor
# 245  696c838e-c054-4e9f-a51a-50bf5660f364  tutor
# 246  8fe03f08-8581-430c-a590-9888ab36deb3  tutor
# 247  8fe03f08-8581-430c-a590-9888ab36deb3  tutor
#
# [248 rows x 8 columns]

# %% [markdown]
# **Считаем среднюю оценку за уроки для каждого преподователя в определенный день**

# %%
mean_phys = lessons_phys_quality.groupby(['moscow_date', 'tutor_id']).agg({'tech_quality': 'mean'}).reset_index()
mean_phys.columns = ['moscow_date', 'tutor_id', 'average_score']
mean_phys['average_score'] = mean_phys['average_score'].round(2)        # округляем до двух знаков
mean_phys.sort_values(by='average_score').head()                        # сортировка по возрастанию
# Out:
#    moscow_date                              tutor_id  average_score
# 46  2020-01-16  2fa2ab62-f1b0-4036-872f-bcfd9a8686ff           4.00
# 37  2020-01-14  c6718d0e-976c-4d6c-b0e0-32c770776567           4.00
# 71  2020-01-18  43efce48-94b2-4412-857f-223d45969008           4.25
# 7   2020-01-11  8fe03f08-8581-430c-a590-9888ab36deb3           4.43
# 92  2020-01-20  43efce48-94b2-4412-857f-223d45969008           4.50

# %% [markdown]
# **Минимальная средняя оценка за урок в определенный день**

# %%
mean_phys_min = mean_phys.groupby(['moscow_date'])['average_score'].min().reset_index()
mean_phys_min
# Out:
#   moscow_date  average_score
# 0  2020-01-11           4.43
# 1  2020-01-12           4.89
# 2  2020-01-13           5.00
# 3  2020-01-14           4.00
# 4  2020-01-15           5.00
# 5  2020-01-16           4.00
# 6  2020-01-17           4.50
# 7  2020-01-18           4.25
# 8  2020-01-19           4.50
# 9  2020-01-20           4.50

# %% [markdown]
# **Определяем преподователей с минимальными средними оценками за урок в определенный день**

# %%
table = pd.merge(mean_phys_min, mean_phys, how='left', on=['moscow_date','average_score'])
cols = ['moscow_date', 'tutor_id', 'average_score']
table = table[cols]
table
# Out:
#    moscow_date                              tutor_id  average_score
# 0   2020-01-11  8fe03f08-8581-430c-a590-9888ab36deb3           4.43
# 1   2020-01-12  696c838e-c054-4e9f-a51a-50bf5660f364           4.89
# 2   2020-01-13  2fa2ab62-f1b0-4036-872f-bcfd9a8686ff           5.00
# 3   2020-01-13  30a19496-bdaf-461c-abbc-2709ae520201           5.00
# 4   2020-01-13  696c838e-c054-4e9f-a51a-50bf5660f364           5.00
# 5   2020-01-13  b37ccae8-fc31-4ad8-8f55-ca855b23fbf6           5.00
# 6   2020-01-13  be676776-8366-4c71-8a35-d58014806eb5           5.00
# 7   2020-01-14  c6718d0e-976c-4d6c-b0e0-32c770776567           4.00
# 8   2020-01-15  603b8641-c6f6-4d89-ac89-88e50d45aa0d           5.00
# 9   2020-01-15  696c838e-c054-4e9f-a51a-50bf5660f364           5.00
# 10  2020-01-15  9b26952c-3470-4032-a9cd-f1e9d4f90ece           5.00
# 11  2020-01-15  b37ccae8-fc31-4ad8-8f55-ca855b23fbf6           5.00
# 12  2020-01-16  2fa2ab62-f1b0-4036-872f-bcfd9a8686ff           4.00
# 13  2020-01-17  696c838e-c054-4e9f-a51a-50bf5660f364           4.50
# 14  2020-01-18  43efce48-94b2-4412-857f-223d45969008           4.25
# 15  2020-01-19  be676776-8366-4c71-8a35-d58014806eb5           4.50
# 16  2020-01-20  30a19496-bdaf-461c-abbc-2709ae520201           4.50
# 17  2020-01-20  43efce48-94b2-4412-857f-223d45969008           4.50
